# %%
import numpy as np
import pickle
dataset = 'campus'
with open('./work_dir/' + dataset + '/agcn_test_joint/epoch11_test_score.pkl','rb') as f:
    data = pickle.load(f)
with open('./data/' + dataset + '/val_label.pkl','rb') as f:
    label = pickle.load(f)

# %%
# !dir
# Out:
#  ������ F �еľ��� �¼Ӿ�
#  �������к��� 0E36-1EB3
#
#  f:\Code\2s-AGCN-even ��Ŀ¼
#
# 2022/11/18  18:33    <DIR>          .
# 2022/11/17  20:42    <DIR>          ..
# 2022/11/08  15:40            12,292 .DS_Store
# 2019/12/17  11:25             1,270 .gitignore
# 2022/11/18  19:23    <DIR>          .vscode
# 2022/11/17  20:42    <DIR>          config
# 2022/11/17  20:42    <DIR>          data
# 2022/11/18  19:10    <DIR>          data_gen
# 2022/11/08  15:40             2,556 ensemble.py
# 2022/11/17  20:42    <DIR>          feeders
# 2022/11/17  20:42    <DIR>          graph
# 2022/11/07  12:28             3,921 Know.md
# 2019/12/17  11:25            19,331 LICENSE
# 2022/11/19  15:38            24,273 main.py
# 2022/11/17  20:42    <DIR>          model
# 2022/11/19  16:57            10,013 mytest.ipynb
# 2022/11/17  20:42    <DIR>          pic
# 2019/12/17  11:25             2,572 README.md
# 2022/11/18  17:28    <DIR>          runs
# 2022/11/17  20:42    <DIR>          work_dir
# ...

# %%
import numpy as np
import pickle
dataset = 'campus'
with open('./data/' + dataset + '/train_data_joint.npy','rb') as f:
    data = np.load(f)
with open('./data/' + dataset + '/train_label.pkl','rb') as f:
    label = pickle.load(f)
data.shape
# Out:
# (241, 3, 1, 17, 4)

# %%
label[1].__len__()
# Out:
# 241

# %%
with open(r'.\data\campus\train_data_bone.npy','rb') as f:
    data = np.load(f)

# %%
import pickle
with open(r'F:\Code\2s-AGCN-even\work_dir\campus\agcn_test_bone2\epoch11_test_score.pkl','rb') as f:
    label = pickle.load(f)
label
# Out:
# {1388: array([-4.604356  ,  1.8714898 ,  1.590457  ,  1.1111008 ,  0.17366962,
#         -0.10666037,  0.23667143, -0.3201679 ], dtype=float32),
#  1389: array([-4.604356  ,  1.1111008 ,  1.8714898 ,  1.590457  ,  0.17366962,
#         -0.10666037,  0.23667143, -0.3201679 ], dtype=float32),
#  1390: array([-4.604356  ,  1.1111008 ,  1.8714898 ,  1.590457  ,  0.17366962,
#         -0.10666037,  0.23667143, -0.3201679 ], dtype=float32),
#  1391: array([-4.604356  ,  1.1111008 ,  1.590457  ,  1.8714898 ,  0.17366962,
#         -0.10666037,  0.23667143, -0.3201679 ], dtype=float32),
#  1392: array([-4.5900755 ,  1.8305552 ,  1.5579768 ,  1.1455247 ,  0.17815275,
#         -0.05084116,  0.22120576, -0.3234647 ], dtype=float32),
#  1393: array([-4.5900755 ,  1.1455247 ,  1.5579768 ,  1.8305552 ,  0.17815275,
#         -0.05084116,  0.22120576, -0.3234647 ], dtype=float32),
#  1394: array([-4.5900755 ,  1.1455247 ,  1.8305552 ,  1.5579768 ,  0.17815275,
# ...
